# %%
# !pip install GitPython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['GIT_PYTHON_GIT_EXECUTABLE'] = r'C:\Program Files\Git\bin\git.exe'
from git import Repo

# %%
import subprocess
import csv
import pandas as pd
import requests
import git
import pandas as pd
import json

# %%
os.system("git clone https://github.com/PhonePe/pulse.git")
# Out:
# 128

# %%
root_dir = (r'C:\Users\user\project_phonepe\pulse\data')

# %%
data_list = []
for state_dir in os.listdir(os.path.join(root_dir, r'C:\Users\user\project_phonepe\pulse\data\aggregated\transaction\country\india\state')):
    state_path = os.path.join(root_dir, r'C:\Users\user\project_phonepe\pulse\data\aggregated\transaction\country\india\state', state_dir)
    if os.path.isdir(state_path):
        for year_dir in os.listdir(state_path):
            year_path = os.path.join(state_path, year_dir)
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        with open(os.path.join(year_path,json_file)) as f:
                            data = json.load(f)
                            for transaction_data in data['data']['transactionData']:
                                row_dict = {
                                    'states': state_dir,
                                    'transaction_year': year_dir,
                                    'quarters': int(json_file.split('.')[0]),
                                    'transaction_type': transaction_data['name'],
                                    'transaction_count': transaction_data['paymentInstruments'][0]['count'],
                                    'transaction_amount': transaction_data['paymentInstruments'][0]['amount']
                                }
                                data_list.append(row_dict)

# %%
df1 = pd.DataFrame(data_list)
df1
# Out:
#                          states transaction_year  quarters  \
# 0     andaman-&-nicobar-islands             2018         1
# 1     andaman-&-nicobar-islands             2018         1
# 2     andaman-&-nicobar-islands             2018         1
# 3     andaman-&-nicobar-islands             2018         1
# 4     andaman-&-nicobar-islands             2018         1
# ...                         ...              ...       ...
# 3589                west-bengal             2022         4
# 3590                west-bengal             2022         4
# 3591                west-bengal             2022         4
# 3592                west-bengal             2022         4
# 3593                west-bengal             2022         4
#
#               transaction_type  transaction_count  transaction_amount
# 0     Recharge & bill payments               4200        1.845307e+06
# 1        Peer-to-peer payments               1871        1.213866e+07
# ...

# %%
root_dir = (r"C:\Users\user\project_phonepe\pulse\data\aggregated\user\country\india\state")
df2_list = []
for state_dir in os.listdir(root_dir):
    state_path = os.path.join(root_dir, state_dir)
    if os.path.isdir(state_path):
        for json_file in os.listdir(state_path):
            if json_file.endswith('json'):
                with open(os.path.join(state_path, json_file), 'r') as f:
                    json_data = json.load(f)
                    if isinstance(json_data, list):
                        df2_list += json_data
                    else:
                        df2_list.append(json_data)
        if df2_list:
            df2 = pd.json_normalize(df2_list)
            df2['subfolder'] = state_dir
            df2['subsubfolder'] = 'state'
df2 = pd.DataFrame(data_list)
df2
# Out:
#                          states transaction_year  quarters  \
# 0     andaman-&-nicobar-islands             2018         1
# 1     andaman-&-nicobar-islands             2018         1
# 2     andaman-&-nicobar-islands             2018         1
# 3     andaman-&-nicobar-islands             2018         1
# 4     andaman-&-nicobar-islands             2018         1
# ...                         ...              ...       ...
# 3589                west-bengal             2022         4
# 3590                west-bengal             2022         4
# 3591                west-bengal             2022         4
# 3592                west-bengal             2022         4
# 3593                west-bengal             2022         4
#
#               transaction_type  transaction_count  transaction_amount
# 0     Recharge & bill payments               4200        1.845307e+06
# 1        Peer-to-peer payments               1871        1.213866e+07
# ...

# %%
root_dir = (r'C:\Users\user\project_phonepe\pulse\data')
data_list = []
for state_dir in os.listdir(os.path.join(root_dir, r'C:\Users\user\project_phonepe\pulse\data\map\transaction\hover\country\india\state')):
    state_path = os.path.join(root_dir, r'C:\Users\user\project_phonepe\pulse\data\map\transaction\hover\country\india\state', state_dir)
    if os.path.isdir(state_path):
       
       for year_dir in os.listdir(state_path):
            year_path = os.path.join(state_path, year_dir)
            if os.path.isdir(year_path):
                
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        with open(os.path.join(year_path, json_file))as f:
                            data = json.load(f)
                            
                            for hoverDataList in data['data']['hoverDataList']:
                                row_dict = {
                                    'states': state_dir,
                                    'transaction_year': year_dir,
                                    'quarters': int(json_file.split('.')[0]),
                                    'district': hoverDataList['name'],
                                    'transaction_type': hoverDataList['metric'][0]['type'],
                                    'transaction_count': hoverDataList['metric'][0]['amount']
                                }
                                data_list.append(row_dict)

df3 = pd.DataFrame(data_list)
df3
# Out:
#                           states transaction_year  quarters  \
# 0      andaman-&-nicobar-islands             2018         1
# 1      andaman-&-nicobar-islands             2018         1
# 2      andaman-&-nicobar-islands             2018         1
# 3      andaman-&-nicobar-islands             2018         2
# 4      andaman-&-nicobar-islands             2018         2
# ...                          ...              ...       ...
# 14631                west-bengal             2022         4
# 14632                west-bengal             2022         4
# 14633                west-bengal             2022         4
# 14634                west-bengal             2022         4
# 14635                west-bengal             2022         4
#
#                                 district transaction_type  transaction_count
# 0      north and middle andaman district            TOTAL       9.316631e+05
# 1                 south andaman district            TOTAL       1.256025e+07
# ...

# %%
root_dir = (r"C:\Users\user\project_phonepe\pulse\data\map\user\hover\country\india\state")
data_list = []

for state_dir in os.listdir(root_dir):
    state_path = os.path.join(root_dir, state_dir)
    if os.path.isdir(state_path):
        
        for year_dir in os.listdir(state_path):
            year_path = os.path.join(state_path, year_dir)
            if os.path.isdir(state_path):
                
                for year_dir in os.listdir(state_path):
                    year_path = os.path.join(state_path, year_dir)
                    if os.path.isdir(year_path):
                        
                        for json_file in os.listdir(year_path):
                            if json_file.endswith('.json'):
                                with open(os.path.join(year_path, json_file)) as f:
                                    data = json.load(f)
                                    
                                    for district, values in data['data']['hoverData'].items():
                                        row_dict = {
                                            'states': state_dir,
                                            'transaction_year': year_dir,
                                            'quarter': int(json_file.split('.')[0]),
                                            'district':district,
                                            'registeredusers': values['registeredUsers']
                                        }
                                        data_list.append(row_dict)
        
df4 = pd.DataFrame(data_list)
df4
# Out:
#                           states transaction_year  quarter  \
# 0      andaman-&-nicobar-islands             2018        1
# 1      andaman-&-nicobar-islands             2018        1
# 2      andaman-&-nicobar-islands             2018        1
# 3      andaman-&-nicobar-islands             2018        2
# 4      andaman-&-nicobar-islands             2018        2
# ...                          ...              ...      ...
# 73195                west-bengal             2022        4
# 73196                west-bengal             2022        4
# 73197                west-bengal             2022        4
# 73198                west-bengal             2022        4
# 73199                west-bengal             2022        4
#
#                                 district  registeredusers
# 0      north and middle andaman district              632
# 1                 south andaman district             5846
# 2                      nicobars district              262
# ...

# %%
root_dir = (r'C:\Users\user\project_phonepe\pulse\data')
data_list = []

for state_dir in os.listdir(os.path.join(root_dir, r'C:\Users\user\project_phonepe\pulse\data\top\transaction\country\india\state')):
    state_path = os.path.join(root_dir, r'C:\Users\user\project_phonepe\pulse\data\top\transaction\country\india\state', state_dir)
    if os.path.isdir(state_path):
        
        for year_dir in os.listdir(state_path):
            year_path = os.path.join(state_path, year_dir)
            if os.path.isdir(year_path):
                
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        with open(os.path.join(year_path, json_file)) as f:
                            data = json.load(f)
                            
                            for districts in data['data']['districts']:
                                row_dict = {
                                    'states': state_dir,
                                    'transaction_year': year_dir,
                                    'quarters': int(json_file.split('.')[0]),
                                    'District': districts['entityName'],
                                    'transaction_type': districts['metric']['type'],
                                    'transaction_count': districts['metric']['count'],
                                    'transaction_amount': districts['metric']['amount']
                                }
                                
                                data_list.append(row_dict)

df5 = pd.DataFrame(data_list)
df5
# Out:
#                          states transaction_year  quarters  \
# 0     andaman-&-nicobar-islands             2018         1
# 1     andaman-&-nicobar-islands             2018         1
# 2     andaman-&-nicobar-islands             2018         1
# 3     andaman-&-nicobar-islands             2018         2
# 4     andaman-&-nicobar-islands             2018         2
# ...                         ...              ...       ...
# 5915                west-bengal             2022         4
# 5916                west-bengal             2022         4
# 5917                west-bengal             2022         4
# 5918                west-bengal             2022         4
# 5919                west-bengal             2022         4
#
#                         District transaction_type  transaction_count  \
# 0                  south andaman            TOTAL               5688
# 1                       nicobars            TOTAL                528
# ...

# %%
root_dir = (r'C:\Users\user\project_phonepe\pulse\data\top\user\country\india\state')
data_list = []

for state_dir in os.listdir(root_dir):
    state_path = os.path.join(root_dir, state_dir)
    if os.path.isdir(state_path):
        
        for year_dir in os.listdir(state_path):
            year_path = os.path.join(state_path, year_dir)
            if os.path.isdir(year_path):
                
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        with open(os.path.join(year_path, json_file)) as f:
                            data = json.load(f)
                            
                            for district in data ['data']['districts']:
                                row_dict = {
                                    'state': state_dir,
                                    'transaction_year': year_dir,
                                    'quarters': int(json_file.split('.')[0]),
                                    'districts': district['name'] if 'name' in district else district['pincode'],
                                    'registeredusers': district['registeredUsers'],
                                }
                                data_list.append(row_dict)
                                
df6 = pd.DataFrame(data_list)
df6
# Out:
#                           state transaction_year  quarters  \
# 0     andaman-&-nicobar-islands             2018         1
# 1     andaman-&-nicobar-islands             2018         1
# 2     andaman-&-nicobar-islands             2018         1
# 3     andaman-&-nicobar-islands             2018         2
# 4     andaman-&-nicobar-islands             2018         2
# ...                         ...              ...       ...
# 5915                west-bengal             2022         4
# 5916                west-bengal             2022         4
# 5917                west-bengal             2022         4
# 5918                west-bengal             2022         4
# 5919                west-bengal             2022         4
#
#                      districts  registeredusers
# 0                south andaman             5846
# 1     north and middle andaman              632
# 2                     nicobars              262
# 3                south andaman             8143
# ...

# %%
d1 = df1.drop_duplicates()
d2 = df2.drop_duplicates()
d3 = df3.drop_duplicates()
d4 = df4.drop_duplicates()
d5 = df5.drop_duplicates()
d6 = df6.drop_duplicates()

# %%
null_counts = d1.isnull().sum()
print(null_counts)
# Out:
# states                0
# transaction_year      0
# quarters              0
# transaction_type      0
# transaction_count     0
# transaction_amount    0
# dtype: int64

# %%
null_counts = d2.isnull().sum()
print(null_counts)
# Out:
# states               0
# transaction_year     0
# quarters             0
# district             0
# transaction_type     0
# transaction_couny    0
# dtype: int64

# %%
null_counts = d3.isnull().sum()
print(null_counts)
# Out:
# states               0
# transaction_year     0
# quarters             0
# district             0
# transaction_type     0
# transaction_couny    0
# dtype: int64

# %%
null_counts = d4.isnull().sum()
print(null_counts)
# Out:
# states              0
# transaction_year    0
# quarter             0
# district            0
# registeredusers     0
# dtype: int64

# %%
null_counts = d5.isnull().sum()
print(null_counts)
# Out:
# states                0
# transaction_year      0
# quarters              0
# transaction_type      0
# transaction_count     0
# transaction_amount    0
# dtype: int64

# %%
null_counts = d6.isnull().sum()
print(null_counts)
# Out:
# state               0
# transaction_year    0
# quarters            0
# districts           0
# registeredusers     0
# dtype: int64

# %%
d1.to_csv('agg_trans.csv', index=False)
d2.to_csv('agg_user.csv', index=False)
d3.to_csv('map_tran.csv', index=False)
d4.to_csv('map_user.csv', index=False)
d5.to_csv('top_tran.csv', index=False)
d6.to_csv('top_user.csv', index=False)

# %%
import mysql.connector as sql
mydb = sql.connect(host="localhost",
                     user="root",
                     password="12345",
                     database="phonepe")
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("create table agg_trans (state varchar(50), year int, quarter int, transaction_type varchar(100), transaction_count int, transaction_amount double)")

for i,row in df1.iterrows():
    sql = "INSERT INTO agg_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 mycursor.execute("create table agg_trans (state varchar(50), year int, quarter int, transaction_type varchar(100), transaction_count int, transaction_amount double)")
#       3 for i,row in df1.iterrows():
#       4     sql = "INSERT INTO agg_trans VALUES (%s,%s,%s,%s,%s,%s)"
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:615, in MySQLCursor.execute(self, operation, params, multi)
#     612     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     614 try:
# --> 615     self._handle_result(self._connection.cmd_query(stmt))
#     616 except InterfaceError as err:
#     617     if self._connection.have_next_result:
#
# ...

# %%
mycursor.execute("create table agg_users (state varchar(50), year int, quarter int, district varchar(50), registered_users varchar(50))")
for i,row in df2.iterrows():
    sql = "INSERT INTO agg_users VALUES (%s,%s,%s,%s,%s%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[29], line 4
#       2 for i,row in df2.iterrows():
#       3     sql = "INSERT INTO agg_users VALUES (%s,%s,%s,%s,%s%s)"
# ----> 4     mycursor.execute(sql, tuple(row))
#       5     mydb.commit()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:598, in MySQLCursor.execute(self, operation, params, multi)
#     596 elif isinstance(params, (list, tuple)):
#     597     psub = _ParamSubstitutor(self._process_params(params))
# --> 598     stmt = RE_PY_PARAM.sub(psub, stmt)
#     599     if psub.remaining != 0:
#     600         raise ProgrammingError(
#     601             "Not all parameters were used in the SQL statement"
#     602         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:127, in _ParamSubstitutor.__call__(self, matchobj)
# ...

# %%
mycursor.execute("create table map_tran (state varchar(50), year int, quarter int, district varchar(50), transaction_type varchar(50), transaction_count int)")

for i,row in df3.iterrows():
    sql = "INSERT INTO map_tran VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       3 for i,row in df3.iterrows():
#       4     sql = "INSERT INTO map_tran VALUES (%s,%s,%s,%s,%s,%s)"
# ----> 5     mycursor.execute(sql, tuple(row))
#       6     mydb.commit()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:615, in MySQLCursor.execute(self, operation, params, multi)
#     612     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     614 try:
# --> 615     self._handle_result(self._connection.cmd_query(stmt))
#     616 except InterfaceError as err:
#     617     if self._connection.have_next_result:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\connection.py:1046, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#    1044 query = bytes(packet)
#    1045 try:
# ...

# %%
mycursor.execute("create table map_user (state varchar(50), year int, quarter int, district varchar(50), registered_user int)")

for i,row in df4.iterrows():
    sql = "INSERT INTO map_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mycursor.execute("create table map_user (state varchar(50), year int, quarter int, district varchar(50), registered_user int)")
#       3 for i,row in df4.iterrows():
#       4     sql = "INSERT INTO map_user VALUES (%s,%s,%s,%s,%s,%s)"
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:615, in MySQLCursor.execute(self, operation, params, multi)
#     612     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     614 try:
# --> 615     self._handle_result(self._connection.cmd_query(stmt))
#     616 except InterfaceError as err:
#     617     if self._connection.have_next_result:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\connection.py:1046, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
mycursor.execute("create table top_tran (state varchar(50), year int, quarter int, district varchar(50), transaction_type varchar(50), transaction_count int, transaction_amount double)")

for i,row in df5.iterrows():
    sql = "INSERT INTO top_tran VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[33], line 5
#       3 for i,row in df5.iterrows():
#       4     sql = "INSERT INTO top_tran VALUES (%s,%s,%s,%s,%s,%s)"
# ----> 5     mycursor.execute(sql, tuple(row))
#       6     mydb.commit()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:600, in MySQLCursor.execute(self, operation, params, multi)
#     598     stmt = RE_PY_PARAM.sub(psub, stmt)
#     599     if psub.remaining != 0:
# --> 600         raise ProgrammingError(
#     601             "Not all parameters were used in the SQL statement"
#     602         )
#     603 else:
#     604     raise ProgrammingError(
#     605         f"Could not process parameters: {type(params).__name__}({params}),"
#     606         " it must be of type list, tuple or dict"
#     607     )
#
# ...

# %%
mycursor.execute("create table top_user (state varchar(50), year int, quarter int, district varchar(50), registered_user int)")

for i,row in df6.iterrows():
    sql = "INSERT INTO top_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[34], line 5
#       3 for i,row in df6.iterrows():
#       4     sql = "INSERT INTO top_user VALUES (%s,%s,%s,%s,%s,%s)"
# ----> 5     mycursor.execute(sql, tuple(row))
#       6     mydb.commit()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:598, in MySQLCursor.execute(self, operation, params, multi)
#     596 elif isinstance(params, (list, tuple)):
#     597     psub = _ParamSubstitutor(self._process_params(params))
# --> 598     stmt = RE_PY_PARAM.sub(psub, stmt)
#     599     if psub.remaining != 0:
#     600         raise ProgrammingError(
#     601             "Not all parameters were used in the SQL statement"
#     602         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:127, in _ParamSubstitutor.__call__(self, matchobj)
# ...

# %%
mycursor.execute("show tables")
mycursor.fetchall()
# Out:
# [('agg_trans',),
#  ('agg_users',),
#  ('map_tran',),
#  ('map_user',),
#  ('top_tran',),
#  ('top_user',)]

# %%
import pandas as pd
import streamlit as st
import plotly.express as px
import os
import json
from streamlit_option_menu import option_menu
from PIL import Image
from git.repo.base import Repo

# %%
with st.sidebar:
    selected = option_menu("Menu", ["Home","Top Charts","Explore Data","About"],
                          icons=["house","graph-up-arrow","bar-chart-line","exclamation-circle"],
                          menu_icon = "menu-button-wide",
                          default_index=0,
                          styles={"nav-link": {"font-size": "20px", "text-align": "left", "margin": "-2px", "--hover-color":"#0d05f2"},
                                 "nav-link-selected": {"background-color": "#9ff205"}})
# Out:
# 2023-08-19 13:57:14.931 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2023-08-19 13:57:15.710
# ...
#   command:
#
#     streamlit run C:\Users\user\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
if selected == "Home":
    st.markdown("# :black[Data Visualization and Exploration]")
    st.markdown("## :black[A User-Friendly Tool Using Streamlit and Plotly]")
    col1,col2 = st.columns([3,2],gap="medium")
    with col1:
        st.write(" ")
        st.write(" ")
        st.markdown("### :black[Domain :] Data Science")
        st.markdown("### :black[Technologies used :] Github Cloning, Python, Pandas, MySQL, mysql-connector-python, Streamlit, and Plotly.")

# %%
import streamlit as st
selected = st.sidebar.selectbox("Select an option", ("Top Charts", "Other Option"))
if selected == "Top Charts":
    st.markdown("## :black[Top Charts]")
    Type = st.sidebar.selectbox("**Type**", ("Transactions", "Users"))
    column1, column2= st.columns([1,1.5],gap='large')
    with column1:
        Year = st.slider("**Year**", min_value=2018, max_value=2022)
        Quarter = st.slider("Quarter", min_value=1, max_value=4)
        
    with column2:
        st.info(
               """
               #### From this menu we can get insights like :
               - Overall ranking on a particular year and quarter.
               - Top 10 state, district, pincode based on total number of transaction and total amount spent on phonepe
               - Top 10 state, district, pincode based on total phonepe users and their app opening frequency
               - Top 10 mobile brands and its percentage based on the how many people use phonepe
               """,icon="🔍"
              )
        if Type == "Transaction":
            col1,col2,col3 = st.columns([1,1,1],gap="small")
            with col1:
                st.markdown("### :black[States]")
                mycursor.execute(f"select states, sum(transaction_count) as total_transactions_count, sum(transaction_amount) as total from agg_trans where year = {Year} and quarter = {Quarter} group by state order by Total desc limit 10")
                df = pd.DataFrame(mycursor.fetchall(), columns=['states', 'transaction_count', 'transaction_amount'])
                fig = px.pie(df, values='transaction_amount',
                             names='states',
                             title='top 10',
                             color_discrete_sequence=px.colors.sequential.Agsunset,
                             hover_data=['transaction_count'],
                             labels={'transaction_count':'transcation_count'})
                fig.update_traces(textposition='inside', textinfo='percent+label')
                st.plotly_chart(fig,use_container_width=True)
            with col2:
                st.markdown("### :black[districts]")
                mycursor.execute(f"select districts, sum(count) as total_count, sum(amount) as total from map_trans where year = {Year} and quarter = {Quarter} group by district order by Total desc limit 10")
                df = pd.DataFrame(mycursor.fetchall(), columns=['district', 'transaction_count', 'total_amount'])
                fig = px.pie(df, values='total_amount',
                             names='district',
                             title=' top 10',
                             color_discrete_sequence=px.colors.sequential.Agsunset,
                             hover_data=['transaction_count'],
                             labels={'transaction_count':'transcation_count'})
                fig.update_traces(textposition='inside', textinfo='percent+label')
                st.plotly_chart(fig,use_container_width=True)
            with col3:
                st.markdown("### :black[State]")
                mycursor.execute(f"select district, sum(transaction_count) as total_transaction_count, sum(transaction_amount) as total from top_trans where year = {year} and quarter = {Quarter} group by pincode order by Total desc limit 10")
                df = pd.DataFrame(mycursor.fetchall(), columns=['district', 'transaction_count', 'total_amount'])
                fig = px.pie(df, values='total_amount',
                             names='pincode',
                             title=' top 10',
                             color_discrete_sequence=px.colors.sequential.Agsunset,
                             hover_data=['transaction_count'],
                             labels={'transaction_count':'transcation_count'})
                fig.update_traces(textposition='inside', textinfo='percent+label')
                st.plotly_chart(fig,use_container_width=True)
# Out:
# 2023-08-20 19:43:59.010
# ...
#   command:
#
#     streamlit run C:\Users\user\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2023-08-20 19:43:59.017 Session state does not function when running a script without `streamlit run`

# %%
if Type == "Users":
    col1,col2,col3,col4 = st.columns([2,2,2,2],gap="small")
    with col1:
        st.markdown("### :black[Brands]")
        if Year == 2022 and Quarter in [2,3,4]:
            st.markdown("### No Data to Display for 2022 Qtr 2,3,4")
        else:
            mycursor.exceute(f"select brands, sum(count as Total_count, avg(percentage)*100 as Avg_Percentage from agg_user where year = {Year} and quarter = {Quarter} group by brands order by Total_count desc limit 10")
            df = pd.DataFrame(mycursor.fetchall(), columns=['Brand', 'Total_Users', 'Avg_Percentage'])
            fig = px.bar(df,
                         title='Top 10',
                         x="Total_Users",
                         y="Brand",
                         orientation='h',
                         color='Avg_Percentage',
                         color_continous_scale=px.colors.sequential.Agsunset)
            st.plotly_chart(fig,use_container_width=True)
    with col2:
        st.markdown("### :black[districts]")
        mycursor.execute(f"select districts, sum(Registered_user) as Total_Users, sum(app_opens) as Total_Appopens from map_user where year = {Year} and quarter = {Quarter} group by district order by Total_User desc limit 10")
        df = pd.DataFrame(mycursor.fetchall(), columns=['districts', 'Total_Users','Total_Appopens'])
        df.Total_Users = df.Total_Users.astype(float)
        fig = px.bar(df,
                     title='Top 10',
                     x="Total_Users",
                     y="districts",
                     orientation='h',
                     color='total_user',
                     color_countinous_scale=px.colors.sequential.Agsunset)
        st.plotly_chart(fig,use_container_width=True)
    with col3:
        st.markdown("### :black[Pincode]")
        mycursor.execute(f"select Pincode, sum(registeredusers) as Total_user from top_user from where year = {Year} and quarter = {Quarter} group by Pincode order by total_users desc limit 10")
        df = pd.Dataframe(mycursor.fetchall(), columns=['Pincode', 'Total_Users'])
        fig = px.pie(df,
                     values='Total_Users',
                     names='Pincode',
                     title='Top 10',
                     color_discrete_sequencebox=px.colors.sequential.Agsunset,
                     hover_data=['Total_User'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
        st.plotly_chart(fig,use_container_width=True)
    with col4:
        st.markdown("### :black[states]")
        mycursor.execute(f"select state, sum(registeredusers) as Total_users, sum(App_opens) as Total_Appopens from map_user where year = {Year} and quarter = {Quarter} group by state order by Total_Users desc limit 10")
        df = pd.DataFrame(mycursor.fetchall(), columns=['states', 'Total_Users', 'Total_Appopens'])
        fig = px.pie(df,
                     values='Total_Users',
                     names='states',
                     title='Top 10',
                     color_discrete_sequence=px.colors.sequential.Agsunset,
                     hover_data=['Total_Appopens'],
                     labels={'Total_Appopens':'Total_Appopens'})
        fig.update_traces(textposition='inside', textinfo='percent+label')
        st.plotly_chart(fig,use_container_width=True)

# %%
import streamlit as st
selected = st.sidebar.selectbox("Select an option", ["Explore Data", "Other Option"])
if selected == "Explore Data":
        Year = st.sidebar.slider("**Year**", min_value=2018, max_value=2022)
        Quarter = st.sidebar.slider("Quarter", min_value=1, max_value=4)
        Type = st.sidebar.selectbox("**Type**", ("Transactions", "Users"))
        col1,col2 = st.columns(2)
        
        if Type == "Transactions":
            with col1:
                st.markdown("## :black[Overall state Data - Transactions Amount]")
                mycursor.execute(f"SELECT state, SUM(transaction_count) as Total_Transactions, SUM(amount) as Total_amount FROM map_tran WHERE year = {Year} AND quarter = {Quarter} GROUP BY state ORDER BY state")
                df1 = pd.DataFrame(mycursor.fetchall(),columns=['State', 'Total_Transactions', 'Total_Amount'])
                df2 = Pd.read_csv('Statenames.csv')
            df1.State = df2
            fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                      featureidkey='properties.ST_NM',
                      locations='State',
                      color='Total_amount',
                      color_continuous_scale='sunset')

            fig.update_geos(fitbounds="locations", visible=False)
            st.plotly_chart(fig,use_container_width=True)
            
        with col2:
            
            st.markdown("## :violet[Overall State Data - Transactions Count]")
            mycursor.execute(f"SELECT state, SUM(transaction_count) as Total_Transactions, SUM(Transactions_amount) as Total_amount FROM map_tran WHERE year = {Year} AND quarter = {Quarter} GROUP BY state ORDER BY state")
            df1 = pd.DataFrame(mycursor.fetchall(),columns= ['State', 'Total_Transactions', 'Total_amount'])
            df2 = pd.read_csv('Statenames.csv')
            df1.Total_Transactions = df1.Total_Transactions.astype(int)
            df1.State = df2

            fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                      featureidkey='properties.ST_NM',
                      locations='State',
                      color='Total_Transactions',
                      color_continuous_scale='sunset')

            fig.update_geos(fitbounds="locations", visible=False)
            st.plotly_chart(fig,use_container_width=True)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[39], line 12
#      10 with col1:
#      11     st.markdown("## :black[Overall state Data - Transactions Amount]")
# ---> 12     mycursor.execute(f"SELECT state, SUM(transaction_count) as Total_Transactions, SUM(amount) as Total_amount FROM map_tran WHERE year = {Year} AND quarter = {Quarter} GROUP BY state ORDER BY state")
#      13     df1 = pd.DataFrame(mycursor.fetchall(),columns=['State', 'Total_Transactions', 'Total_Amount'])
#      14     df2 = Pd.read_csv('Statenames.csv')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\cursor.py:615, in MySQLCursor.execute(self, operation, params, multi)
#     612     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     614 try:
# --> 615     self._handle_result(self._connection.cmd_query(stmt))
#     616 except InterfaceError as err:
# ...

# %%
if Type == "Users":
    st.markdown("## :black[Overall State Data - User App opening frequency]")
    mycursor.execute(f"select States, sum(RegisteredUsers) as Total_Users from map_user where Transaction_Year = {Year} and Quarters = {Quarter} group by States order by States")
    df1 = pd.DataFrame(mycursor.fetchall(), columns=['State', 'Total_Users','Total_Appopens'])
    df2 = pd.read_csv('Statenames.csv')
    df1.Total_Appopens = df1.Total_Appopens.astype(float)
    df1.State = df2
    fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                        featureidkey='properties.ST_NM',
                        locations='State',
                        color='Total_Appopens',
                        color_continuous_scale='sunset')
    fig.update_geos(fitbounds="locations", visible=False)
    st.plotly_chart(fig,use_container_width=True)

# %%
if selected == "About":
    col1,col2 = st.columns([3,3],gap="medium")
    with col1:
        st.write(" ")
        st.write(" ")
        st.markdown("### :violet[About PhonePe Pulse:] ")
    with col2:
        st.write(" ")
        st.write(" ")
        st.write(" ")
        st.write(" ")
